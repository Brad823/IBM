# %% [markdown]
# # Capstone Project - The Battle of Neighbourhoods
#
# ### London New Business Analysis

# %% [markdown]
# ## 0 - Import required libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

import seaborn as sns

# %% [markdown]
# ## 1 -  Import London Borough Datasets
#
# Import London Boroughs and London Earnings datasets into Panda dataframe

# %% [markdown]
# First import Wikipedia data.

# %%
london_boroughs = pd.read_csv('/Users/Paul/Coding/Git Projects/IBM/Data sources/LondonBoroughs.csv')

# ensure Population is a float data type
london_boroughs['Population'] = london_boroughs['Population'].astype(float)

print (london_boroughs.head())
# Out:
#                 Borough                              Local authority  \
# 0  Barking and Dagenham  Barking and Dagenham London Borough Council
# 1                Barnet                Barnet London Borough Council
# 2                Bexley                Bexley London Borough Council
# 3                 Brent                 Brent London Borough Council
# 4               Bromley               Bromley London Borough Council
#
#   Political Control  Area sq_miles  Population  Latitude  Longitude
# 0            Labour          13.93    194352.0   51.5607     0.1557
# 1      Conservative          33.49    369088.0   51.6252    -0.1517
# 2      Conservative          23.38    236687.0   51.4549     0.1505
# 3            Labour          16.70    317264.0   51.5588    -0.2817
# 4      Conservative          57.97    317899.0   51.4039     0.0198

# %% [markdown]
# And next do the Earnings data next

# %%
london_earnings = pd.read_csv('/Users/Paul/Coding/Git Projects/IBM/Data sources/2019earnings.csv')

#drop code column and rename area to Borough. 
london_earnings.drop(['Code'], axis=1, inplace=True)
london_earnings.rename(columns={'Area':'Borough'}, inplace=True)

print(london_earnings.head())
# Out:
#                 Borough  Hourly  Full Time £
# 0  Barking and Dagenham                15.09
# 1                Barnet                17.73
# 2                Bexley                16.97
# 3                 Brent                15.67
# 4               Bromley                20.90

# %% [markdown]
# Now merge two datasets together

# %%
#merge datasets into new dataset
london = london_boroughs.join(london_earnings.set_index('Borough'), on='Borough')
print(london.head())
# Out:
#                 Borough                              Local authority  \
# 0  Barking and Dagenham  Barking and Dagenham London Borough Council
# 1                Barnet                Barnet London Borough Council
# 2                Bexley                Bexley London Borough Council
# 3                 Brent                 Brent London Borough Council
# 4               Bromley               Bromley London Borough Council
#
#   Political Control  Area sq_miles  Population  Latitude  Longitude  \
# 0            Labour          13.93    194352.0   51.5607     0.1557
# 1      Conservative          33.49    369088.0   51.6252    -0.1517
# 2      Conservative          23.38    236687.0   51.4549     0.1505
# 3            Labour          16.70    317264.0   51.5588    -0.2817
# 4      Conservative          57.97    317899.0   51.4039     0.0198
#
#    Hourly  Full Time £
# 0                15.09
# 1                17.73
# 2                16.97
# 3                15.67
# 4                20.90

# %% [markdown]
# ## 2 - Analyse datasets using Visualisation

# %% [markdown]
# Examine Population size first

# %%
# create simple dataset to do analysis

lon_pop = london[['Borough', 'Population']] 
lon_pop = lon_pop.sort_values('Population', ascending=True)

# %%
# and then chart
lon_pop.plot(kind='barh', figsize=(10, 10), x='Borough')

plt.xlabel('Borough') # add to x-label to the plot
plt.ylabel('Population Size') # add y-label to the plot
plt.title('London Boroughs by Population Size') # add title to the plot

plt.show()

# %% [markdown]
# and then Population density

# %%
#create a new column to hold density by 1000 people
london["Population_Density"] = (london["Population"]/1000) / london["Area sq_miles"]
lon_popden = london[['Borough', 'Population_Density']] 

lon_popden = lon_popden.sort_values('Population_Density', ascending=True)

print (lon_popden.head())
# Out:
#                  Borough  Population_Density
# 4                Bromley            5.483854
# 14              Havering            5.584314
# 15            Hillingdon            6.420551
# 25  Richmond upon Thames            8.631710
# 8                Enfield           10.098425

# %%
# and then chart
lon_popden.plot(kind='barh', figsize=(10, 10), x='Borough', color='grey' )

plt.xlabel('Population Density - 000s per square mile') # add to x-label to the plot
plt.ylabel('Borough') # add y-label to the plot
plt.title('London Boroughs by Population Density') # add title to the plot

plt.show()

# %% [markdown]
# then earning per borough.

# %%
lon_earning = london[['Borough', 'Hourly  Full Time £']] 

lon_earning = lon_earning.sort_values('Hourly  Full Time £', ascending=True)

print (lon_earning.head())
# Out:
#                  Borough  Hourly  Full Time £
# 0   Barking and Dagenham                15.09
# 7                 Ealing                15.66
# 3                  Brent                15.67
# 15            Hillingdon                15.73
# 23                Newham                15.76

# %%
# and then chart
lon_earning.plot(kind='barh', figsize=(10, 10), x='Borough',  color='orange')

plt.xlabel('Hourly Full Time £') # add to x-label to the plot
plt.ylabel('Borough') # add y-label to the plot
plt.title('London Boroughs by Hourly Wage - Full Time £') # add title to the plot

plt.show()

# %% [markdown]
# ## Stage 3 - Analyse venues in each Borough using Foursquare API
#
# Use radius of 5000 metres compared to original coursework given size of London Boroughs.

# %%
# Drop columsn that might interfer with clustering

london = london_boroughs[['Borough', 'Latitude', 'Longitude']]

# %%
CLIENT_ID = 'T1V0AEHTGEZOXW5PJHOLFCTJ5RFVSL5LIHP0TROHQR0ASM2F' 
CLIENT_SECRET = 'CRREFB0Z0KQOBME5XGHDXCRKPVGPOMQYFLMV3TH0AJ3RVHVB'
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # limit of number of venues returned by Foursquare API

# %%
borough_latitude = london.loc[0, 'Latitude'] # borough latitude value
borough_longitude = london.loc[0, 'Longitude'] # borough longitude value

borough_name = london.loc[0, 'Borough'] # neighbourhood name

print('Latitude and longitude values of {} are {}, {}.'.format(borough_name, borough_latitude, borough_longitude))
# Out:
# Latitude and longitude values of Barking and Dagenham are 51.5607, 0.1557.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=5000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Borough', 
                  'Borough Latitude', 
                  'Borough Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
london_venues = getNearbyVenues(names=london['Borough'],
                                   latitudes=london['Latitude'],
                                   longitudes=london['Longitude']
                                  )
# Out:
# Barking and Dagenham
# Barnet
# Bexley
# Brent
# Bromley
# Camden
# Croydon
# Ealing
# Enfield
# Greenwich
# Hackney
# Hammersmith and Fulham
# Haringey
# Harrow
# Havering
# Hillingdon
# Hounslow
# Islington
# Kensington and Chelsea
# Kingston upon Thames
# Lambeth
# Lewisham
# Merton
# Newham
# Redbridge
# Richmond upon Thames
# Southwark
# Sutton
# Tower Hamlets
# Waltham Forest
# Wandsworth
# Westminster

# %%
# one hot encoding
london_onehot = pd.get_dummies(london_venues[['Venue Category']], prefix="", prefix_sep="")

# add borough column back to dataframe
london_onehot['Borough'] = london_venues['Borough'] 

# move borough column to the first column
fixed_columns = [london_onehot.columns[-1]] + list(london_onehot.columns[:-1])
london_onehot = london_onehot[fixed_columns]

# %%
london_grouped = london_onehot.groupby('Borough').mean().reset_index()

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Borough']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
borough_venues_sorted = pd.DataFrame(columns=columns)
borough_venues_sorted['Borough'] = london_grouped['Borough']

for ind in np.arange(london_grouped.shape[0]):
    borough_venues_sorted.iloc[ind, 1:] = return_most_common_venues(london_grouped.iloc[ind, :], num_top_venues)

print (borough_venues_sorted.head())
# Out:
#                 Borough 1st Most Common Venue 2nd Most Common Venue  \
# 0  Barking and Dagenham           Supermarket         Grocery Store
# 1                Barnet                  Café           Coffee Shop
# 2                Bexley                   Pub         Grocery Store
# 3                 Brent     Indian Restaurant                   Pub
# 4               Bromley           Coffee Shop                   Pub
#
#   3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0           Coffee Shop                  Park                        Pub
# 1                  Park    Turkish Restaurant                Supermarket
# 2           Supermarket           Coffee Shop         Italian Restaurant
# 3           Supermarket           Coffee Shop  Middle Eastern Restaurant
# 4                  Park         Grocery Store                Pizza Place
#
#       6th Most Common Venue   7th Most Common Venue 8th Most Common Venue  \
# 0        Italian Restaurant                    Café  Fast Food Restaurant
# 1  Mediterranean Restaurant        Greek Restaurant                Bakery
# 2            Clothing Store  Furniture / Home Store              Pharmacy
# 3                      Park    Gym / Fitness Center                  Café
# 4         Indian Restaurant    Gym / Fitness Center                  Café
#
#       9th Most Common Venue 10th Most Common Venue
# 0                    Bakery   Gym / Fitness Center
# 1      Gym / Fitness Center                    Pub
# 2                      Park   Fast Food Restaurant
# 3     Portuguese Restaurant            Pizza Place
# 4  Mediterranean Restaurant              Gastropub

# %%
# set number of clusters
kclusters = 5

london_grouped_clustering = london_grouped.drop('Borough', 1)


# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(london_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 2, 3, 4, 3, 0, 3, 1, 2, 3], dtype=int32)

# %%
# add clustering labels
borough_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

london_merged = london

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
london_merged = london_merged.join(borough_venues_sorted.set_index('Borough'), on='Borough')

london_merged # check the last columns!
# Out:
#                    Borough  Latitude  Longitude  Cluster Labels  \
# 0     Barking and Dagenham   51.5607     0.1557               3
# 1                   Barnet   51.6252    -0.1517               2
# 2                   Bexley   51.4549     0.1505               3
# 3                    Brent   51.5588    -0.2817               4
# 4                  Bromley   51.4039     0.0198               3
# 5                   Camden   51.5290    -0.1255               0
# 6                  Croydon   51.3714    -0.0977               3
# 7                   Ealing   51.5130    -0.3089               1
# 8                  Enfield   51.6538    -0.0799               2
# 9                Greenwich   51.4892     0.0648               3
# 10                 Hackney   51.5450    -0.0553               2
# 11  Hammersmith and Fulham   51.4927    -0.2339               2
# 12                Haringey   51.6000    -0.1119               2
# 13                  Harrow   51.5898    -0.3346               4
# 14                Havering   51.5812     0.1837               3
# 15              Hillingdon   51.5441    -0.4760               3
# 16                Hounslow   51.4746    -0.3680               1
# 17               Islington   51.5416    -0.1022               0
# 18  Kensington and Chelsea   51.5020    -0.1947               0
# 19    Kingston upon Thames   51.4085    -0.3064               1
# 20                 Lambeth   51.4607    -0.1163               2
# 21                Lewisham   51.4452    -0.0209               1
# 22                  Merton   51.4014    -0.1958               1
# 23                  Newham   51.5077     0.0469               3
# 24               Redbridge   51.5590     0.0741               3
# 25    Richmond upon Thames   51.4479    -0.3260               1
# 26               Southwark   51.5035    -0.0804               0
# 27                  Sutton   51.3618    -0.1945               3
# 28           Tower Hamlets   51.5099    -0.0059               1
# 29          Waltham Forest   51.5908    -0.0134               1
# 30              Wandsworth   51.4567    -0.1910               2
# 31             Westminster   51.4973    -0.1372               0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0            Supermarket         Grocery Store           Coffee Shop
# 1                   Café           Coffee Shop                  Park
# 2                    Pub         Grocery Store           Supermarket
# 3      Indian Restaurant                   Pub           Supermarket
# 4            Coffee Shop                   Pub                  Park
# 5                  Hotel             Bookstore            Steakhouse
# 6                    Pub                  Park         Grocery Store
# 7                    Pub           Coffee Shop                  Park
# 8                    Pub           Coffee Shop    Turkish Restaurant
# 9                    Pub                  Park           Coffee Shop
# 10                   Pub           Coffee Shop                  Café
# 11                  Café           Coffee Shop                   Pub
# 12    Turkish Restaurant           Coffee Shop                  Café
# 13     Indian Restaurant           Coffee Shop                  Park
# 14           Coffee Shop         Grocery Store           Supermarket
# 15                   Pub           Coffee Shop         Grocery Store
# 16                   Pub                  Park           Coffee Shop
# 17                 Hotel          Cocktail Bar           Coffee Shop
# 18                 Hotel                  Café                Garden
# 19                   Pub                  Café                  Park
# 20                  Park           Coffee Shop                  Café
# 21                   Pub                  Park           Coffee Shop
# 22                   Pub                  Park           Coffee Shop
# 23                   Pub                 Hotel                  Park
# 24                  Park                   Pub         Grocery Store
# 25                   Pub                  Park                Garden
# 26                 Hotel               Theater          Cocktail Bar
# 27                  Park           Coffee Shop                   Pub
# 28                   Pub                  Park           Coffee Shop
# 29                   Pub           Coffee Shop                  Park
# 30                  Park           Coffee Shop                  Café
# 31                 Hotel          Cocktail Bar                Lounge
#
#    4th Most Common Venue      5th Most Common Venue     6th Most Common Venue  \
# 0                   Park                        Pub        Italian Restaurant
# 1     Turkish Restaurant                Supermarket  Mediterranean Restaurant
# 2            Coffee Shop         Italian Restaurant            Clothing Store
# 3            Coffee Shop  Middle Eastern Restaurant                      Park
# 4          Grocery Store                Pizza Place         Indian Restaurant
# 5            Pizza Place                    Theater              Cocktail Bar
# 6            Coffee Shop                Supermarket               Pizza Place
# 7                   Café                      Hotel          Botanical Garden
# 8   Gym / Fitness Center                       Park                      Café
# 9                  Hotel       Gym / Fitness Center             Historic Site
# 10                Bakery               Cocktail Bar                      Park
# 11  Gym / Fitness Center                Pizza Place                 Gastropub
# 12                   Pub                       Park  Mediterranean Restaurant
# 13                   Pub                       Café      Gym / Fitness Center
# 14                   Pub                       Café        Italian Restaurant
# 15              Pharmacy                Pizza Place         Indian Restaurant
# 16     Indian Restaurant      Portuguese Restaurant               Supermarket
# 17                   Pub                Pizza Place                    Market
# 18             Juice Bar                       Park               Art Gallery
# 19           Coffee Shop                     Garden               Supermarket
# 20           Pizza Place         Italian Restaurant                   Theater
# 21                  Café          Indian Restaurant                Beer Store
# 22                  Café                        Bar          Sushi Restaurant
# 23           Coffee Shop       Gym / Fitness Center                      Café
# 24           Supermarket                       Café         Indian Restaurant
# 25           Coffee Shop                       Café        Italian Restaurant
# 26           Coffee Shop             Scenic Lookout     Street Food Gathering
# 27         Grocery Store                Supermarket                      Café
# 28                  Café                        Bar                    Garden
# 29           Pizza Place                       Café                   Brewery
# 30                   Pub                Pizza Place         French Restaurant
# 31           Art Gallery                  Bookstore                Steakhouse
#
#         7th Most Common Venue 8th Most Common Venue     9th Most Common Venue  \
# 0                        Café  Fast Food Restaurant                    Bakery
# 1            Greek Restaurant                Bakery      Gym / Fitness Center
# 2      Furniture / Home Store              Pharmacy                      Park
# 3        Gym / Fitness Center                  Café     Portuguese Restaurant
# 4        Gym / Fitness Center                  Café  Mediterranean Restaurant
# 5                 Coffee Shop           Art Gallery         Indian Restaurant
# 6    Mediterranean Restaurant        Clothing Store                     Hotel
# 7   Middle Eastern Restaurant           Pizza Place                    Bakery
# 8               Garden Center           Supermarket             Grocery Store
# 9               Grocery Store        Clothing Store                    Garden
# 10                Pizza Place             Bookstore                  Beer Bar
# 11                       Park     Fish & Chips Shop                    Bakery
# 12                     Bakery                 Trail               Pizza Place
# 13      Portuguese Restaurant    Italian Restaurant               Supermarket
# 14                       Park  Fast Food Restaurant                    Bakery
# 15                Supermarket        Sandwich Place                     Hotel
# 16                       Café         Rugby Stadium                     Hotel
# 17                 Steakhouse      Sushi Restaurant               Flea Market
# 18        Japanese Restaurant     Indian Restaurant          Department Store
# 19               Burger Joint             Gastropub         German Restaurant
# 20                     Market            Beer Store                       Bar
# 21                        Bar    Italian Restaurant             Garden Center
# 22         Italian Restaurant        Tennis Stadium               Supermarket
# 23         Turkish Restaurant         Historic Site                     Plaza
# 24                Pizza Place         Train Station                       Gym
# 25              Rugby Stadium                 Hotel                    Bakery
# 26           Sushi Restaurant                Garden                       Pub
# 27         Italian Restaurant           Pizza Place            Clothing Store
# 28             History Museum                  Farm        Turkish Restaurant
# 29            Nature Preserve    Italian Restaurant                Restaurant
# 30             Tennis Stadium        Soccer Stadium                    Bakery
# 31                    Theater                  Park                Art Museum
#
#        10th Most Common Venue
# 0        Gym / Fitness Center
# 1                         Pub
# 2        Fast Food Restaurant
# 3                 Pizza Place
# 4                   Gastropub
# 5              Ice Cream Shop
# 6        Gym / Fitness Center
# 7            Sushi Restaurant
# 8            Greek Restaurant
# 9            Asian Restaurant
# 10                    Brewery
# 11          Indian Restaurant
# 12            Organic Grocery
# 13  Middle Eastern Restaurant
# 14             Clothing Store
# 15       Gym / Fitness Center
# 16                        Gym
# 17                     Bakery
# 18                  Hotel Bar
# 19                  Gift Shop
# 20                        Pub
# 21          Fish & Chips Shop
# 22               Burger Joint
# 23               Burger Joint
# 24                Coffee Shop
# 25             Scenic Lookout
# 26                Pizza Place
# 27                      Hotel
# 28                   Beer Bar
# 29       Gym / Fitness Center
# 30                Yoga Studio
# 31                      Plaza

# %% [raw]
# Create a map of London Area

# %%
# create map - use London long/lat

map_clusters = folium.Map(location=[51.5074, -0.1278], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(london_merged['Latitude'], london_merged['Longitude'], london_merged['Borough'], london_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
london_merged.loc[london_merged['Cluster Labels'] == 0, london_merged.columns[[0] + list(range(3, london_merged.shape[1]))]]
# Out:
#                    Borough  Cluster Labels 1st Most Common Venue  \
# 5                   Camden               0                 Hotel
# 17               Islington               0                 Hotel
# 18  Kensington and Chelsea               0                 Hotel
# 26               Southwark               0                 Hotel
# 31             Westminster               0                 Hotel
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 5              Bookstore            Steakhouse           Pizza Place
# 17          Cocktail Bar           Coffee Shop                   Pub
# 18                  Café                Garden             Juice Bar
# 26               Theater          Cocktail Bar           Coffee Shop
# 31          Cocktail Bar                Lounge           Art Gallery
#
#    5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 5                Theater           Cocktail Bar           Coffee Shop
# 17           Pizza Place                 Market            Steakhouse
# 18                  Park            Art Gallery   Japanese Restaurant
# 26        Scenic Lookout  Street Food Gathering      Sushi Restaurant
# 31             Bookstore             Steakhouse               Theater
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 5            Art Gallery     Indian Restaurant         Ice Cream Shop
# 17      Sushi Restaurant           Flea Market                 Bakery
# 18     Indian Restaurant      Department Store              Hotel Bar
# 26                Garden                   Pub            Pizza Place
# 31                  Park            Art Museum                  Plaza

# %%
london_merged.loc[london_merged['Cluster Labels'] == 1, london_merged.columns[[0] + list(range(3, london_merged.shape[1]))]]
# Out:
#                  Borough  Cluster Labels 1st Most Common Venue  \
# 7                 Ealing               1                   Pub
# 16              Hounslow               1                   Pub
# 19  Kingston upon Thames               1                   Pub
# 21              Lewisham               1                   Pub
# 22                Merton               1                   Pub
# 25  Richmond upon Thames               1                   Pub
# 28         Tower Hamlets               1                   Pub
# 29        Waltham Forest               1                   Pub
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 7            Coffee Shop                  Park                  Café
# 16                  Park           Coffee Shop     Indian Restaurant
# 19                  Café                  Park           Coffee Shop
# 21                  Park           Coffee Shop                  Café
# 22                  Park           Coffee Shop                  Café
# 25                  Park                Garden           Coffee Shop
# 28                  Park           Coffee Shop                  Café
# 29           Coffee Shop                  Park           Pizza Place
#
#     5th Most Common Venue 6th Most Common Venue      7th Most Common Venue  \
# 7                   Hotel      Botanical Garden  Middle Eastern Restaurant
# 16  Portuguese Restaurant           Supermarket                       Café
# 19                 Garden           Supermarket               Burger Joint
# 21      Indian Restaurant            Beer Store                        Bar
# 22                    Bar      Sushi Restaurant         Italian Restaurant
# 25                   Café    Italian Restaurant              Rugby Stadium
# 28                    Bar                Garden             History Museum
# 29                   Café               Brewery            Nature Preserve
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 7            Pizza Place                Bakery       Sushi Restaurant
# 16         Rugby Stadium                 Hotel                    Gym
# 19             Gastropub     German Restaurant              Gift Shop
# 21    Italian Restaurant         Garden Center      Fish & Chips Shop
# 22        Tennis Stadium           Supermarket           Burger Joint
# 25                 Hotel                Bakery         Scenic Lookout
# 28                  Farm    Turkish Restaurant               Beer Bar
# 29    Italian Restaurant            Restaurant   Gym / Fitness Center

# %%
london_merged.loc[london_merged['Cluster Labels'] == 2, london_merged.columns[[0] + list(range(3, london_merged.shape[1]))]]
# Out:
#                    Borough  Cluster Labels 1st Most Common Venue  \
# 1                   Barnet               2                  Café
# 8                  Enfield               2                   Pub
# 10                 Hackney               2                   Pub
# 11  Hammersmith and Fulham               2                  Café
# 12                Haringey               2    Turkish Restaurant
# 20                 Lambeth               2                  Park
# 30              Wandsworth               2                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1            Coffee Shop                  Park    Turkish Restaurant
# 8            Coffee Shop    Turkish Restaurant  Gym / Fitness Center
# 10           Coffee Shop                  Café                Bakery
# 11           Coffee Shop                   Pub  Gym / Fitness Center
# 12           Coffee Shop                  Café                   Pub
# 20           Coffee Shop                  Café           Pizza Place
# 30           Coffee Shop                  Café                   Pub
#
#    5th Most Common Venue     6th Most Common Venue 7th Most Common Venue  \
# 1            Supermarket  Mediterranean Restaurant      Greek Restaurant
# 8                   Park                      Café         Garden Center
# 10          Cocktail Bar                      Park           Pizza Place
# 11           Pizza Place                 Gastropub                  Park
# 12                  Park  Mediterranean Restaurant                Bakery
# 20    Italian Restaurant                   Theater                Market
# 30           Pizza Place         French Restaurant        Tennis Stadium
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1                 Bakery  Gym / Fitness Center                    Pub
# 8            Supermarket         Grocery Store       Greek Restaurant
# 10             Bookstore              Beer Bar                Brewery
# 11     Fish & Chips Shop                Bakery      Indian Restaurant
# 12                 Trail           Pizza Place        Organic Grocery
# 20            Beer Store                   Bar                    Pub
# 30        Soccer Stadium                Bakery            Yoga Studio

# %%
london_merged.loc[london_merged['Cluster Labels'] == 3, london_merged.columns[[0] + list(range(3, london_merged.shape[1]))]]
# Out:
#                  Borough  Cluster Labels 1st Most Common Venue  \
# 0   Barking and Dagenham               3           Supermarket
# 2                 Bexley               3                   Pub
# 4                Bromley               3           Coffee Shop
# 6                Croydon               3                   Pub
# 9              Greenwich               3                   Pub
# 14              Havering               3           Coffee Shop
# 15            Hillingdon               3                   Pub
# 23                Newham               3                   Pub
# 24             Redbridge               3                  Park
# 27                Sutton               3                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Grocery Store           Coffee Shop                  Park
# 2          Grocery Store           Supermarket           Coffee Shop
# 4                    Pub                  Park         Grocery Store
# 6                   Park         Grocery Store           Coffee Shop
# 9                   Park           Coffee Shop                 Hotel
# 14         Grocery Store           Supermarket                   Pub
# 15           Coffee Shop         Grocery Store              Pharmacy
# 23                 Hotel                  Park           Coffee Shop
# 24                   Pub         Grocery Store           Supermarket
# 27           Coffee Shop                   Pub         Grocery Store
#
#    5th Most Common Venue 6th Most Common Venue     7th Most Common Venue  \
# 0                    Pub    Italian Restaurant                      Café
# 2     Italian Restaurant        Clothing Store    Furniture / Home Store
# 4            Pizza Place     Indian Restaurant      Gym / Fitness Center
# 6            Supermarket           Pizza Place  Mediterranean Restaurant
# 9   Gym / Fitness Center         Historic Site             Grocery Store
# 14                  Café    Italian Restaurant                      Park
# 15           Pizza Place     Indian Restaurant               Supermarket
# 23  Gym / Fitness Center                  Café        Turkish Restaurant
# 24                  Café     Indian Restaurant               Pizza Place
# 27           Supermarket                  Café        Italian Restaurant
#
#    8th Most Common Venue     9th Most Common Venue 10th Most Common Venue
# 0   Fast Food Restaurant                    Bakery   Gym / Fitness Center
# 2               Pharmacy                      Park   Fast Food Restaurant
# 4                   Café  Mediterranean Restaurant              Gastropub
# 6         Clothing Store                     Hotel   Gym / Fitness Center
# 9         Clothing Store                    Garden       Asian Restaurant
# 14  Fast Food Restaurant                    Bakery         Clothing Store
# 15        Sandwich Place                     Hotel   Gym / Fitness Center
# 23         Historic Site                     Plaza           Burger Joint
# 24         Train Station                       Gym            Coffee Shop
# 27           Pizza Place            Clothing Store                  Hotel

# %%
london_merged.loc[london_merged['Cluster Labels'] == 4, london_merged.columns[[0] + list(range(3, london_merged.shape[1]))]]
# Out:
#    Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 3    Brent               4     Indian Restaurant                   Pub
# 13  Harrow               4     Indian Restaurant           Coffee Shop
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 3            Supermarket           Coffee Shop  Middle Eastern Restaurant
# 13                  Park                   Pub                       Café
#
#    6th Most Common Venue  7th Most Common Venue 8th Most Common Venue  \
# 3                   Park   Gym / Fitness Center                  Café
# 13  Gym / Fitness Center  Portuguese Restaurant    Italian Restaurant
#
#     9th Most Common Venue     10th Most Common Venue
# 3   Portuguese Restaurant                Pizza Place
# 13            Supermarket  Middle Eastern Restaurant
